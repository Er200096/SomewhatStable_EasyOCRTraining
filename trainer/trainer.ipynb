# %%
import os
import torch.backends.cudnn as cudnn
import yaml
from train import train
from utils import AttrDict
import pandas as pd

# %%
cudnn.benchmark = True
cudnn.deterministic = False

# %%
def get_config(file_path):
    with open(file_path, 'r', encoding="utf8") as stream:
        opt = yaml.safe_load(stream)
    opt = AttrDict(opt)
    if opt.lang_char == 'None':
        characters = ''
        for data in opt['select_data'].split('-'):
            csv_path = os.path.join(opt['train_data'], data, 'labels.csv')
            df = pd.read_csv(csv_path, sep='^([^,]+),', engine='python', usecols=['filename', 'words'], keep_default_na=False)
            all_char = ''.join(df['words'])
            characters += ''.join(set(all_char))
        characters = sorted(set(characters))
        opt.character= ''.join(characters)
    else:
        opt.character = opt.number + opt.symbol + opt.lang_char
    os.makedirs(f'./saved_models/{opt.experiment_name}', exist_ok=True)
    return opt

# %%
opt = get_config("config_files/en_filtered_config.yaml")
train(opt, amp=False)
# Out:
# Filtering the images containing characters which are not in opt.character
# Filtering the images whose label is longer than opt.batch_max_length
# --------------------------------------------------------------------------------
# dataset_root: C:/Users/MANGANI2.2/Documents/BilletOCR/EasyOCR/trainer/all_data/BillteOCR_train
# opt.select_data: ['BillteOCR']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    C:/Users/MANGANI2.2/Documents/BilletOCR/EasyOCR/trainer/all_data/BillteOCR_train	 dataset: BillteOCR
# C:/Users/MANGANI2.2/Documents/BilletOCR/EasyOCR/trainer/all_data/BillteOCR_train/
# the label is  8411
# the label is  8411
# the label is  8410
# the label is  8408
# the label is  8408
# the label is  8408
# the label is  8408
# the label is  8
# the label is  8408
# the label is  8408
# the label is  8408
# the label is  8408
# the label is  8408
# the label is  8410
# the label is  8408
# the label is  8408
# the label is  8408
# the label is  8408
# the label is  8408
# the label is  8408
# the label is  8408
# the label is  8408
# the label is  8408
# the label is  8410
# the label is  8408
# the label is  8408
# the label is  8408
# the label is  8408
# the label is  8408
# the label is  408
# the label is  8408
# the label is  8408
# the label is  8410
# the label is  8409
# the label is  8407
# the label is  8407
# the label is  8407
# the label is  8407
# the label is  8407
# the label is  8407
# the label is  8407
# the label is  8410
# the label is  8407
# the label is  8407
# the label is  8407
# the label is  8407
# the label is  8407
# the label is  8407
# the label is  8407
# the label is  8407
# the label is  8407
# the label is  8410
# the label is  8437
# the label is  840
# the label is  8407
# the label is  4407
# the label is  8407
# the label is  0
# the label is  8410
# the label is  8407
# the label is  8407
# the label is  8407
# the label is  8407
# the label is  8407
# the label is  8407
# the label is  8407
# the label is  840
# the label is  8406
# the label is  8410
# the label is  8406
# the label is  8406
# the label is  8406
# the label is  8406
# the label is  8406
# the label is  8406
# the label is  8406
# the label is  8410
# the label is  8406
# the label is  8406
# the label is  8406
# the label is  8406
# the label is  8406
# the label is  8406
# the label is  8406
# the label is  8410
# the label is  8406
# the label is  8406
# the label is  8406
# the label is  8406
# the label is  8406
# the label is  8406
# the label is  8406
# the label is  8406
# the label is  8406
# the label is  8411
# the label is  8410
# the label is  8406
# the label is  8406
# the label is  8406
# the label is  8406
# the label is  8406
# the label is  8406
# the label is  8406
# the label is  8406
# the label is  8405
# the label is  10
# the label is  8405
# the label is  8405
# the label is  8405
# the label is  8405
# the label is  8405
# the label is  8405
# the label is  8405
# the label is  8405
# the label is  8410
# the label is  405
# the label is  8405
# the label is  8405
# the label is  8405
# the label is  8405
# the label is  8405
# the label is  8405
# the label is  8405
# the label is  8405
# the label is  8405
# the label is  8410
# the label is  8405
# the label is  2405
# the label is  8405
# the label is  8405
# the label is  8405
# the label is  8404
# the label is  8404
# the label is  10
# the label is  8404
# the label is  8404
# the label is  8404
# the label is  8404
# the label is  8404
# the label is  8404
# the label is  8404
# the label is  8404
# the label is  84
# the label is  8410
# the label is  8404
# the label is  8404
# the label is  8404
# the label is  8404
# the label is  8404
# the label is  8404
# the label is  8404
# the label is  8404
# the label is  8404
# the label is  8404
# the label is  8404
# the label is  8404
# the label is  8404
# the label is  8404
# the label is  8404
# the label is  8410
# the label is  8404
# the label is  8404
# the label is  8404
# the label is  8404
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8410
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8410
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8411
# the label is  8410
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8
# the label is  8403
# the label is  8403
# the label is  8403
# the label is  8402
# the label is  8402
# the label is  8402
# the label is  8402
# the label is  8402
# the label is  8410
# the label is  8402
# the label is  8402
# the label is  8402
# the label is  2
# the label is  8402
# the label is  8402
# the label is  2
# the label is  3
# the label is  8402
# the label is  8410
# the label is  8402
# the label is  8402
# the label is  8402
# the label is  8402
# the label is  8402
# the label is  8402
# the label is  8402
# the label is  8410
# the label is  8402
# the label is  8402
# the label is  8402
# the label is  8402
# the label is  8402
# the label is  8402
# the label is  8402
# the label is  8402
# the label is  8402
# the label is  8410
# the label is  8402
# the label is  8402
# the label is  8402
# the label is  8402
# the label is  8402
# the label is  8402
# the label is  840
# the label is  8410
# the label is  8401
# the label is  8401
# the label is  841
# the label is  8401
# the label is  8401
# the label is  8401
# the label is  8401
# the label is  8401
# the label is  8410
# the label is  8401
# the label is  8401
# the label is  8401
# the label is  8401
# the label is  8401
# the label is  8401
# the label is  84
# the label is  8401
# the label is  8401
# the label is  8401
# the label is  8410
# the label is  8401
# the label is  8401
# the label is  X1
# the label is  8401
# the label is  8401
# the label is  8401
# the label is  8401
# the label is  8401
# the label is  8401
# the label is  8401
# the label is  8401
# the label is  8401
# the label is  8401
# the label is  8401
# the label is  8400
# the label is  8400
# the label is  8410
# the label is  8400
# the label is  8400
# the label is  8400
# the label is  8400
# the label is  8400
# the label is  8400
# the label is  8400
# the label is  8400
# the label is  8400
# the label is  8400
# the label is  8400
# the label is  8410
# the label is  8400
# the label is  8400
# the label is  8400
# sub-directory:	/.	 num samples: 301
# num total samples of BillteOCR: 301 x 1.0 (total_data_usage_ratio) = 301
# num samples of BillteOCR per batch: 32 x 1.0 (batch_ratio) = 32
# --------------------------------------------------------------------------------
# Total_batch_size: 32 = 32
# --------------------------------------------------------------------------------
# dataset_root:    C:/Users/MANGANI2.2/Documents/BilletOCR/EasyOCR/trainer/all_data/BillteOCR_val	 dataset: /
# C:/Users/MANGANI2.2/Documents/BilletOCR/EasyOCR/trainer/all_data/BillteOCR_val/
# the label is  8400
# the label is  8400
# the label is  8400
# the label is  8400
# the label is  8400
# the label is  8
# the label is  8410
# the label is  8400
# the label is  8400
# the label is  8400
# the label is  8400
# the label is  8400
# the label is  8400
# the label is  8400
# the label is  8400
# the label is  8400
# the label is  8400
# the label is  8410
# the label is  8
# the label is  8400
# the label is  8400
# the label is  8400
# the label is  481
# the label is  8481
# the label is  8410
# the label is  8481
# the label is  8181
# the label is  8410
# the label is  8481
# the label is  8410
# the label is  8481
# the label is  8481
# the label is  848
# the label is  2410
# the label is  8481
# the label is  8490
# the label is  8490
# the label is  8490
# the label is  8490
# the label is  8410
# the label is  8490
# the label is  8490
# the label is  8490
# the label is  8449
# the label is  8490
# the label is  8490
# the label is  8490
# the label is  8490
# the label is  8409
# the label is  8490
# the label is  90
# the label is  8490
# the label is  8497
# the label is  8411
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  8411
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  409
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  84
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  8411
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  8409
# the label is  8410
# the label is  8409
# the label is  8408
# the label is  8408
# the label is  8408
# the label is  8408
# the label is  8408
# the label is  8408
# the label is  8408
# the label is  8408
# sub-directory:	/.	 num samples: 104
# --------------------------------------------------------------------------------
# No Transformation module specified
# model input parameters 64 600 20 1 256 256 97 34 None VGG BiLSTM CTC
# loading pretrained model from saved_models/BillteOCR/english_g2.pth
# Model:
# DataParallel(
#   (module): Model(
#     (FeatureExtraction): VGG_FeatureExtractor(
#       (ConvNet): Sequential(
#         (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): ReLU(inplace=True)
#         (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (7): ReLU(inplace=True)
#         (8): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (9): ReLU(inplace=True)
#         (10): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (11): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (12): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (13): ReLU(inplace=True)
#         (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (16): ReLU(inplace=True)
#         (17): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (18): Conv2d(256, 256, kernel_size=(2, 2), stride=(1, 1))
#         (19): ReLU(inplace=True)
#       )
#     )
#     (AdaptiveAvgPool): AdaptiveAvgPool2d(output_size=(None, 1))
#     (SequenceModeling): Sequential(
#       (0): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#       (1): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#     )
#     (Prediction): Linear(in_features=256, out_features=97, bias=True)
#   )
# )
# Modules, Parameters
# module.FeatureExtraction.ConvNet.0.weight 288
# module.FeatureExtraction.ConvNet.0.bias 32
# module.FeatureExtraction.ConvNet.3.weight 18432
# module.FeatureExtraction.ConvNet.3.bias 64
# module.FeatureExtraction.ConvNet.6.weight 73728
# module.FeatureExtraction.ConvNet.6.bias 128
# module.FeatureExtraction.ConvNet.8.weight 147456
# module.FeatureExtraction.ConvNet.8.bias 128
# module.FeatureExtraction.ConvNet.11.weight 294912
# module.FeatureExtraction.ConvNet.12.weight 256
# module.FeatureExtraction.ConvNet.12.bias 256
# module.FeatureExtraction.ConvNet.14.weight 589824
# module.FeatureExtraction.ConvNet.15.weight 256
# module.FeatureExtraction.ConvNet.15.bias 256
# module.FeatureExtraction.ConvNet.18.weight 262144
# module.FeatureExtraction.ConvNet.18.bias 256
# module.SequenceModeling.0.rnn.weight_ih_l0 262144
# module.SequenceModeling.0.rnn.weight_hh_l0 262144
# module.SequenceModeling.0.rnn.bias_ih_l0 1024
# module.SequenceModeling.0.rnn.bias_hh_l0 1024
# module.SequenceModeling.0.rnn.weight_ih_l0_reverse 262144
# module.SequenceModeling.0.rnn.weight_hh_l0_reverse 262144
# module.SequenceModeling.0.rnn.bias_ih_l0_reverse 1024
# module.SequenceModeling.0.rnn.bias_hh_l0_reverse 1024
# module.SequenceModeling.0.linear.weight 131072
# module.SequenceModeling.0.linear.bias 256
# module.SequenceModeling.1.rnn.weight_ih_l0 262144
# module.SequenceModeling.1.rnn.weight_hh_l0 262144
# module.SequenceModeling.1.rnn.bias_ih_l0 1024
# module.SequenceModeling.1.rnn.bias_hh_l0 1024
# module.SequenceModeling.1.rnn.weight_ih_l0_reverse 262144
# module.SequenceModeling.1.rnn.weight_hh_l0_reverse 262144
# module.SequenceModeling.1.rnn.bias_ih_l0_reverse 1024
# module.SequenceModeling.1.rnn.bias_hh_l0_reverse 1024
# module.SequenceModeling.1.linear.weight 131072
# module.SequenceModeling.1.linear.bias 256
# module.Prediction.weight 24832
# module.Prediction.bias 97
# Total Trainable Params: 3781345
# Trainable params num :  3781345
# Optimizer:
# Adadelta (
# Parameter Group 0
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     lr: 1.0
#     maximize: False
#     rho: 0.95
#     weight_decay: 0
# )
# ------------ Options -------------
# number: 0123456789
# symbol: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~ €
# lang_char: ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# experiment_name: BillteOCR
# train_data: C:/Users/MANGANI2.2/Documents/BilletOCR/EasyOCR/trainer/all_data/BillteOCR_train
# valid_data: C:/Users/MANGANI2.2/Documents/BilletOCR/EasyOCR/trainer/all_data/BillteOCR_val
# manualSeed: 1111
# workers: 6
# batch_size: 32
# num_iter: 200
# valInterval: 20000
# saved_model: saved_models/BillteOCR/english_g2.pth
# FT: False
# optim: False
# lr: 1.0
# beta1: 0.9
# rho: 0.95
# eps: 1e-08
# grad_clip: 5
# select_data: ['BillteOCR']
# batch_ratio: ['1']
# total_data_usage_ratio: 1.0
# batch_max_length: 34
# imgH: 64
# imgW: 600
# rgb: False
# contrast_adjust: 0.0
# sensitive: True
# PAD: True
# data_filtering_off: False
# Transformation: None
# FeatureExtraction: VGG
# SequenceModeling: BiLSTM
# Prediction: CTC
# num_fiducial: 20
# input_channel: 1
# output_channel: 256
# hidden_size: 256
# decode: greedy
# new_prediction: False
# freeze_FeatureFxtraction: False
# freeze_SequenceModeling: False
# character: 0123456789!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~ €ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# num_class: 97
# ---------------------------------------
#
# end the training
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\MANGANI2.2\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
